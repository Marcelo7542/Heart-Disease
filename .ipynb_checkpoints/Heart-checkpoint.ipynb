# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Raw = pd.read_csv('heart.csv')

# %%
Raw.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
Raw.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
Raw[Raw.columns[0]]
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
Data_X = Raw.iloc[:, 0:13]

# %%
Data_X.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal
# 0   2     3
# 1   0     3
# 2   0     3
# 3   1     3
# 4   3     2

# %%
Data_Y = Raw.iloc[:,13]

# %%
Data_Y.head(5)
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(Data_X, Data_Y,test_size=0.2, random_state=60)

# %%
print(X_train)
print(Y_train)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 239   62    0   0       150   244    0        1      154      1      1.4
# 389   63    1   3       145   233    1        0      150      0      2.3
# 731   52    1   0       112   230    0        1      160      0      0.0
# 856   68    0   2       120   211    0        0      115      0      1.5
# 816   70    1   1       156   245    0        0      143      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 399   63    1   3       145   233    1        0      150      0      2.3
# 394   63    1   0       130   330    1        0      132      1      1.8
# 582   55    1   1       130   262    0        1      155      0      0.0
# 65    59    1   3       170   288    0        0      159      0      0.2
# 205   42    1   3       148   244    0        0      178      0      0.8
#
#      slope  ca  thal
# 239      1   0     2
# 389      0   0     1
# 731      2   1     2
# ...

# %%
melhor_auc = 0
melhores_parametros = {}
for C in [0.0001,0.001,0.01,0.1,1,10,100,1000]:
        for solver in ['lbfgs','liblinear','saga']:
            for class_weight in [None,'balanced']:
                for tol in [1e-3,1e-4,1e-5]:
                    for max_iter in [500,1000,2000]:
    
                        if solver == 'lbfgs':
                            penalty = 'l2'
    
                            Modelo = Pipeline([('scaler', StandardScaler()),('clf', LogisticRegression(random_state=60,C=C,solver=solver,class_weight=class_weight,tol=tol,max_iter=max_iter,penalty=penalty))])
                            auc_medio = cross_val_score(Modelo,X_train,Y_train,cv=5,scoring='roc_auc').mean()
    
                            print(f"C={C:<8} "f"solver={solver:<10} "f"class_weight={str(class_weight):<8} "f"tol={tol:<8} "f"max_iter={max_iter:<5} "f"AUC={auc_medio:.4f}")
    
                            if auc_medio > melhor_auc:
                                melhor_auc = auc_medio
                                melhores_parametros = {'C': C,'solver': solver,'class_weight': class_weight,'tol': tol,'max_iter': max_iter,'penalty': penalty}
    
                        else:
                            for penalty in ['l1','l2']:
    
                                Modelo = Pipeline([('scaler', StandardScaler()),('clf', LogisticRegression(random_state=60,C=C,solver=solver,class_weight=class_weight,tol=tol,max_iter=max_iter,penalty=penalty))])
    
                                auc_medio = cross_val_score(Modelo,X_train,Y_train,cv=5,scoring='roc_auc').mean()
    
                                print(f"C={C:<8} "f"solver={solver:<10} "f"penalty={penalty:<2} "f"class_weight={str(class_weight):<8} "f"tol={tol:<8} "f"max_iter={max_iter:<5} "f"AUC={auc_medio:.4f}")
    
                                if auc_medio > melhor_auc:
                                    melhor_auc = auc_medio
                                    melhores_parametros = {'C': C,'solver': solver,'penalty': penalty,'class_weight': class_weight,'tol': tol,'max_iter': max_iter}
# Out:
# C=0.0001   solver=lbfgs      class_weight=None     tol=0.001    max_iter=500   AUC=0.9089
# C=0.0001   solver=lbfgs      class_weight=None     tol=0.001    max_iter=1000  AUC=0.9089
# C=0.0001   solver=lbfgs      class_weight=None     tol=0.001    max_iter=2000  AUC=0.9089
# C=0.0001   solver=lbfgs      class_weight=None     tol=0.0001   max_iter=500   AUC=0.9088
# C=0.0001   solver=lbfgs      class_weight=None     tol=0.0001   max_iter=1000  AUC=0.9088
# C=0.0001   solver=lbfgs      class_weight=None     tol=0.0001   max_iter=2000  AUC=0.9088
# C=0.0001   solver=lbfgs      class_weight=None     tol=1e-05    max_iter=500   AUC=0.9089
# C=0.0001   solver=lbfgs      class_weight=None     tol=1e-05    max_iter=1000  AUC=0.9089
# C=0.0001   solver=lbfgs      class_weight=None     tol=1e-05    max_iter=2000  AUC=0.9089
# C=0.0001   solver=lbfgs      class_weight=balanced tol=0.001    max_iter=500   AUC=0.9089
# ...

# %%
print(melhores_parametros)
print(melhor_auc)
# Out:
# {'C': 1000, 'solver': 'liblinear', 'penalty': 'l1', 'class_weight': None, 'tol': 0.001, 'max_iter': 500}
# 0.9211663983978241

# %%
Modelo = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression(random_state=60,C=melhores_parametros['C'],solver=melhores_parametros['solver'],class_weight=melhores_parametros['class_weight'],tol=melhores_parametros['tol'],max_iter=melhores_parametros['max_iter'],penalty=melhores_parametros['penalty']))
])
Modelo.fit(X_test, Y_test)
Y_pred = Modelo.predict(X_test)

# %%
Cross = cross_val_score(Modelo,X_test,Y_test, scoring='roc_auc')
print(Cross)
print(Cross.mean())
# Out:
# [0.95238095 0.93095238 0.93333333 0.90430622 0.88516746]
# 0.9212280701754386

# %%
resultado = classification_report(Y_test, Y_pred, output_dict=True)

# %%
Resultado = pd.DataFrame(resultado).transpose()
Resultado
# Out:
#               precision    recall  f1-score     support
# 0              0.875000  0.857143  0.865979   98.000000
# 1              0.871560  0.887850  0.879630  107.000000
# accuracy       0.873171  0.873171  0.873171    0.873171
# macro avg      0.873280  0.872497  0.872805  205.000000
# weighted avg   0.873204  0.873171  0.873104  205.000000

# %%
cm = confusion_matrix(Y_test, Y_pred)
matrix = ConfusionMatrixDisplay(confusion_matrix=cm)
matrix.plot(cmap=plt.cm.Blues)
plt.title('Matrix de confusão')
plt.show()
